# %% [markdown]
# # Getting the data from the website

# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.yelp.com/biz/tesla-san-francisco?osq=Tesla+Dealership')

# %%
#check request status
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script async src="https://www.google-analytics.com/analytics.js"></script><meta id="emotion-container"><style data-emotion-css="0 xl0fej swh6wo 16s2nge rtcdlu 110vchp tza3mu 1enow5j zbyz55 1clzr6h 1kfrpc3 1lwccx4 xlzvdl d0sgb6 1k57hak 1sufhje 1d56pvc 15j7fnr war30n 79elbk 1gfwrmo 1ez3qjc vyw8yh rigrq3 12y3mxl ralh0w wonnhn s36a9t 9dhnpo 1iikwpv 1422juy 1mrxdyn 1bwnp89 1e4fdj9 gsky inq9gi 1c2abjj 1rw3tz3 1lr1m88 1xfj5g9 12bvu5l 1p2252a hrssq9 1g8th6j wuu41 5588ua pijiis 1afdtvl 1nx1n9o 3jhitf jperk6 tjgdvq ollt2v 1pxws0l 1kq79li 1ljw62o 1peqmen p2pgf9 8h74hi 1gbck26 1g83tkj 70yie2 muegjg 190j3wt 8xs00z 1170h8t 1k09l3a avspch dh50jt 11gvbtp 1cuazig 15serri sq5rtq 9t8tgp 53c188 fksa8h nyitw0 19sk4h4 1x9iesk 1h7ysrc auso3a s78x0b 1wvub96 1ccncw 1r80nfg 1bpulmj m125lk 10y60kr 1bp797t 44o0z1 1t7f977 106vfgv 1p80smk huu450 xp8w2v 1vhakgw 1nv8jdk 18es1no 1wbg20i vtkfg0 s62wli">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:\'\';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:599px){.responsive .responsive-small-display-inline-block{display:inline-block !important;}.responsive .responsive-small-display-block{display:block !important;}.responsive .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:1023px){.responsive .responsive-medium-display-inline-block{display:inline-block !important;}.responsive .responsive-medium-display-block{display:block !important;}.responsive .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1240px){.responsive-biz .responsive-medium-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-medium-display-block{display:block !important;}.responsive-biz .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1143px){.responsive .responsive-desktop-small-display-inline-block{display:inline-block !important ...

# %%
#getting the review block from the website
soup = BeautifulSoup(r.text,'html.parser')
#soup.findAll(class_="comment__09f24__gu0rG css-1sufhje")
divs = soup.findAll(class_="comment__09f24__gu0rG css-1sufhje")

# %%
#adding the review text to review array
reviews = []
for div in divs:
    reviews.append(div.find('span').text)
    #print(div.find('span').text,'\n')

# %% [markdown]
# # Analysing the data

# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import nltk

# %%
df = pd.DataFrame(np.array(reviews),columns=['review'])
len(df['review'])
# Out:
# 10

# %%
#df['review'].apply(lambda x: len(x.split()))
df['word_count']= df['review'].apply(lambda x: len(x.split()))
df['char_count']= df['review'].apply(lambda x: len(x))

# %%
def average_words(x):
    words = x.split()
    return sum(len(word) for word in words)/len(words)

# %%
df['avg_word_length']= df['review'].apply(lambda x: average_words(x))

# %%
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/venkat/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['stopword_coun'] = df['review'].apply(lambda x: len([x for x in x.split() if x in stop_words]))

# %% [markdown]
# # cleaning the data

# %%
# Lower case all words
df['review_lower'] = df['review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
# Remove Punctuation
df['review_nopunc'] = df['review_lower'].str.replace('[^\w\s]', '')
# Out:
# /var/folders/gq/fngx79cs1p34q80fpp8n4x540000gn/T/ipykernel_15751/1004031184.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['review_nopunc'] = df['review_lower'].str.replace('[^\w\s]', '')

# %%
# Remove Stopwords
df['review_nopunc_nostop'] = df['review_nopunc'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words))

# %%
pd.Series(" ".join(df['review_nopunc_nostop']).split()).value_counts()
# Out:
# service          16
# car              13
# tesla            11
# called            9
# appointment       8
#                  ..
# kids              1
# helpful           1
# understanding     1
# incredibly        1
# avoided           1
# Length: 442, dtype: int64

# %%
other_stopwords = ['get', 'us', 'see', 'use', 'said', 'asked', 'day', 'go' 
  'even', 'ive', 'right', 'left', 'always', 'would', 'told', 
  'get', 'us', 'would', 'get', 'one', 'ive', 'go', 'even', 
  'also', 'ever', 'x', 'take', 'let' ]

# %%
df['review_nopunc_nostop_nocommon'] = df['review_nopunc_nostop'].apply(lambda x: "".join(" ".join(x for x in x.split() if x not in other_stopwords)))

# %%
pd.Series(" ".join(df['review_nopunc_nostop_nocommon']).split()).value_counts()
# Out:
# service          16
# car              13
# tesla            11
# called            9
# appointment       8
#                  ..
# understanding     1
# incredibly        1
# shop              1
# long              1
# avoided           1
# Length: 425, dtype: int64

# %% [markdown]
# # Lemmatization

# %%
# Import textblob
from textblob import Word

# %%
#nltk.download('wordnet')
#nltk.download('omw-1.4')
# Lemmatize final review format
df['cleaned_review'] = df['review_nopunc_nostop_nocommon'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
# Out:
# [nltk_data] Downloading package wordnet to /Users/venkat/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/venkat/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.

# %% [markdown]
# # Sentiment analysis

# %%
from textblob import TextBlob

# %%
# Calculate polarity
df['polarity'] = df['cleaned_review'].apply(lambda x: TextBlob(x).sentiment[0])
# Calculate subjectivity
df['subjectivity'] = df['cleaned_review'].apply(lambda x: TextBlob(x).sentiment[1])

# %%
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  Consider the Tesla Model 3. Mine is fun, which...          41         230
# 1  My experience with Tesla has been nothing shor...         397        2066
# 2  This is for our amazing experience with the se...         110         587
# 3  Do you love having your car held hostage for t...          59         309
# 4  I am appalled by the poor service at this Tesl...         134         696
#
#    avg_word_length  stopword_coun  \
# 0         4.609756             14
# 1         4.204030            155
# 2         4.300000             49
# 3         4.254237             24
# 4         4.171642             58
#
#                                         review_lower  \
# 0  consider the tesla model 3. mine is fun, which...
# 1  my experience with tesla has been nothing shor...
# 2  this is for our amazing experience with the se...
# 3  do you love having your car held hostage for t...
# 4  i am appalled by the poor service at this tesl...
#
#                                        review_nopunc  \
# 0  consider the tesla model 3 mine is fun which b...
# 1  my experience with tesla has been nothing shor...
# 2  this is for our amazing experience with the se...
# 3  do you love having your car held hostage for t...
# 4  i am appalled by the poor service at this tesl...
#
#                                 review_nopunc_nostop  \
# 0  consider tesla model 3 mine fun brings joy con...
# 1  experience tesla nothing short complete disast...
# 2  amazing experience service center went beyond ...
# 3  love car held hostage things arent fault locat...
# 4  appalled poor service tesla location first can...
#
#                        review_nopunc_nostop_nocommon  \
# 0  consider tesla model 3 mine fun brings joy con...
# 1  experience tesla nothing short complete disast...
# 2  amazing experience service center went beyond ...
# 3  love car held hostage things arent fault locat...
# 4  appalled poor service tesla location first can...
#
#                                       cleaned_review  polarity  subjectivity
# 0  consider tesla model 3 mine fun brings joy con...  0.400000      0.375000
# 1  experience tesla nothing short complete disast...  0.093529      0.521601
# 2  amazing experience service center went beyond ...  0.213542      0.458333
# 3  love car held hostage thing arent fault locati... -0.066667      0.566667
# 4  appalled poor service tesla location first can... -0.039773      0.462085

# %%
df.drop(['review_lower','review_nopunc','review_nopunc_nostop','review_nopunc_nostop_nocommon'],axis=1,inplace=True)

# %%
df.sort_values(by='polarity')
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  Consider the Tesla Model 3. Mine is fun, which...          41         230
# 1  My experience with Tesla has been nothing shor...         397        2066
# 2  This is for our amazing experience with the se...         110         587
# 3  Do you love having your car held hostage for t...          59         309
# 4  I am appalled by the poor service at this Tesl...         134         696
#
#    avg_word_length  stopword_coun  \
# 0         4.609756             14
# 1         4.204030            155
# 2         4.300000             49
# 3         4.254237             24
# 4         4.171642             58
#
#                                       cleaned_review  polarity  subjectivity
# 0  consider tesla model 3 mine fun brings joy con...  0.400000      0.375000
# 1  experience tesla nothing short complete disast...  0.093529      0.521601
# 2  amazing experience service center went beyond ...  0.213542      0.458333
# 3  love car held hostage thing arent fault locati... -0.066667      0.566667
# 4  appalled poor service tesla location first can... -0.039773      0.462085
